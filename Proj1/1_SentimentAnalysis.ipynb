# %%
import numpy as np
import tensorflow as tf

from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
from tensorflow.keras.callbacks import EarlyStopping

# %%
VOCAB_SIZE = 10000
MAX_LENGTH = 200
EMBEDDING_DIM = 128
LSTM_UNITS = 64

# %%
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=VOCAB_SIZE)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
print("Training samples:", len(x_train))
print("Testing samples:", len(x_test))

print("First review:")
print(x_train[0])

print("First label:")
print(y_train[0])
# Out:
# Training samples: 25000
# Testing samples: 25000
# First review:
# [1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65, 458, 4468, 66, 3941, 4, 173, 36, 256, 5, 25, 100, 43, 838, 112, 50, 670, 2, 9, 35, 480, 284, 5, 150, 4, 172, 112, 167, 2, 336, 385, 39, 4, 172, 4536, 1111, 17, 546, 38, 13, 447, 4, 192, 50, 16, 6, 147, 2025, 19, 14, 22, 4, 1920, 4613, 469, 4, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 1247, 4, 22, 17, 515, 17, 12, 16, 626, 18, 2, 5, 62, 386, 12, 8, 316, 8, 106, 5, 4, 2223, 5244, 16, 480, 66, 3785, 33, 4, 130, 12, 16, 38, 619, 5, 25, 124, 51, 36, 135, 48, 25, 1415, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 407, 16, 82, 2, 8, 4, 107, 117, 5952, 15, 256, 4, 2, 7, 3766, 5, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 7, 4, 2, 1029, 13, 104, 88, 4, 381, 15, 297, 98, 32, 2071, 56, 26, 141, 6, 194, 7486, 18, 4, 226, 22, 21, 134, 476, 26, 480, 5, 144, 30, 5535, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 1334, 88, 12, 16, 283, 5, 16, 4472, 113, 103, 32, 15, 16, 5345, 19, 178, 32]
# First label:
# 1

# %%
x_train = pad_sequences(x_train, maxlen=MAX_LENGTH, padding="post", truncating="post")
x_test = pad_sequences(x_test, maxlen=MAX_LENGTH, padding="post", truncating="post")

# %%
print("Training shape:", x_train.shape)
print("Testing shape:", x_test.shape)
# Out:
# Training shape: (25000, 200)
# Testing shape: (25000, 200)

# %%
model = Sequential(
    [
        Embedding(input_dim=VOCAB_SIZE, output_dim=EMBEDDING_DIM),
        LSTM(LSTM_UNITS),
        Dense(1, activation="sigmoid"),
    ]
)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])

# %%
early_stopping = EarlyStopping(
    monitor="val_loss", patience=5, restore_best_weights=True
)

# %%
history = model.fit(
    x_train,
    y_train,
    epochs=10,
    batch_size=64,
    validation_split=0.2,
    callbacks=[early_stopping],
)
# Out:
# Epoch 1/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.5356 - loss: 0.6865 - val_accuracy: 0.5264 - val_loss: 0.7570
# Epoch 2/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.5608 - loss: 0.6772 - val_accuracy: 0.4998 - val_loss: 0.7116
# Epoch 3/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.6168 - loss: 0.6443 - val_accuracy: 0.6056 - val_loss: 0.6192
# Epoch 4/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.7923 - loss: 0.4815 - val_accuracy: 0.8240 - val_loss: 0.4239
# Epoch 5/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.8778 - loss: 0.3119 - val_accuracy: 0.8556 - val_loss: 0.3653
# Epoch 6/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9175 - loss: 0.2244 - val_accuracy: 0.8616 - val_loss: 0.3476
# Epoch 7/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9455 - loss: 0.1609 - val_accuracy: 0.8624 - val_loss: 0.3638
# Epoch 8/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9657 - loss: 0.1131 - val_accuracy: 0.8602 - val_loss: 0.4155
# Epoch 9/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9773 - loss: 0.0836 - val_accuracy: 0.8616 - val_loss: 0.4824
# Epoch 10/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9841 - loss: 0.0640 - val_accuracy: 0.8608 - val_loss: 0.4951

# %%
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.8479 - loss: 0.3731
# Test Loss: 0.37312132120132446
# Test Accuracy: 0.8479200005531311

# %%
model.save("model.keras")
